# %% [markdown]
# # Mesh Conversion Script
#
# This notebook calls the mesh converter function to convert the MED mesh file to XDMF format and extract markers.

# %%
import sys
sys.path.append('scripts')

# Import the mesh converter function
from meshio_converter_med2xdmf import convert_med_to_xdmf

# %%
# Run conversion - only specify input and output directory
markers = convert_med_to_xdmf(
    mesh_input="mesh/cantilever_beam_3d.med",
    mesh_output_dir="mesh/output"
)
# Out:
# Reading mesh from: mesh/cantilever_beam_3d.med
# Mesh loaded: 44 points, cell types: ['line', 'tetra', 'triangle']
#   ✓ Created: mesh/output/mesh.xdmf
#   ✓ Created: mesh/output/surface.xdmf
#   ✓ Created: mesh/output/solid.xdmf
#
# Conversion complete. Mesh files saved in: mesh/output
#
# Extracting markers...
#   ✓ Markers saved to: mesh/output/markers.json
#
# ...
# MARKERS:
# ...
# {
#     "surface": {
#         "forced_end": {
#             "id": -6,
#             "dim": 2,
#             "name": "forced_end"
#         },
#         "fixed_end": {
#             "id": -7,
#             "dim": 2,
#             "name": "fixed_end"
#         }
#     },
#     "solid": {
#         "Domain": {
#             "id": -8,
#             "dim": 3,
#             "name": "Domain"
#         }
#     }
# }
# ...
#
# Summary:
#   - Surface markers: 2
#     • forced_end: ID=-6, Dim=2
#     • fixed_end: ID=-7, Dim=2
#   - Solid markers: 1
#     • Domain: ID=-8, Dim=3
